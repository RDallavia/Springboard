# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
early = pd.read_excel("/Users/rcd/Desktop/Springboard/MiniProjects/Vancomycin/self-confidence surveys.xlsx", sheet_name="Early 2012-13-14")

# %%
late = pd.read_excel("/Users/rcd/Desktop/Springboard/MiniProjects/Vancomycin/self-confidence surveys.xlsx", sheet_name=" Late 2012-13-14", header=1)

# %%
early.head(5)
# Out:
#   Frequency of Vancomycin Administration Unnamed: 1  \
# 0                                   Year       Dose
# 1                                      1          1
# 2                                      1          1
# 3                                      1          1
# 4                                      1          1
#
#                                           Unnamed: 2  \
# 0  Do you feel confident to treat patients with v...
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#                                           Unnamed: 3  \
# 0  Do you feel confident to choose the initial do...
# 1                                                  2
# 2                                                  2
# 3                                                  4
# 4                                                  2
#
# ...

# %%
early.fillna(0, inplace=True)

# %%
early.columns = early.iloc[0]

# %%
early.drop(0, inplace=True)

# %%
early.head()
# Out:
# 0 Year Dose Do you feel confident to treat patients with vancomycin?  \
# 1    1    1                                                  3
# 2    1    1                                                  4
# 3    1    1                                                  4
# 4    1    1                                                  4
# 5    1    1                                                  2
#
# 0 Do you feel confident to choose the initial dose of vancomycin (condidering renal function)?  \
# 1                                                  2
# 2                                                  2
# 3                                                  4
# 4                                                  2
# 5                                                  3
#
# 0 Do you feel confident to choose a maintenance dose of vancomycin?  \
# 1                                                  3
# 2                                                  3
# ...

# %%
early.Year.value_counts()[:-2]
# Out:
# 1    115
# 2      3
# 0      3
# 3      2
# Name: Year, dtype: int64

# %%
pd.crosstab(early['Year'], early['Dose'], margins=True)[:-3]
# Out:
# Dose  0    1  108  <= 20  <= 30  All
# Year
# 0     3    0    0      0      0    3
# 1     0  105    0     10      0  115
# 2     0    2    0      0      1    3
# 3     1    1    0      0      0    2

# %%
early.pivot_table(values=['1.0', '0.0'], columns=['1yr', '2yr', '2yr+'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/y_/hz1vxjzs1cs561dcc_gdd8k00000gn/T/ipykernel_27471/2392074945.py in <module>
# ----> 1 early.pivot_table(values=['1.0', '0.0'], columns=['1yr', '2yr', '2yr+'])
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    8045         from pandas.core.reshape.pivot import pivot_table
#    8046
# -> 8047         return pivot_table(
#    8048             self,
#    8049             values=values,
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      93         return table.__finalize__(data, method="pivot_table")
#      94
# ...

# %%
pd.crosstab(early['1yr'], early['11x to 20x'])
# Out:
# 11x to 20x  0.0  1.0  9.0
# 1yr
# 0.0           7    0    0
# 1.0         106    9    0
# 115.0         0    0    1

# %%
pd.crosstab(early['1yr'], early['21x to 30x'])
# Out:
# 21x to 30x  0.0  1.0
# 1yr
# 0.0           6    1
# 1.0         115    0
# 115.0         0    1

# %%
pd.crosstab(early['1yr'], early['>30'])
# Out:
# >30    0.0
# 1yr
# 0.0      7
# 1.0    115
# 115.0    1
