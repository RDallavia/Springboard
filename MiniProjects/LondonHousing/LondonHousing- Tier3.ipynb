# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np
import seaborn as sns

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
# a view of the data from 30,000 ft.
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            328 non-null    datetime64[ns]
#  1   City of London        329 non-null    object
#  2   Barking & Dagenham    329 non-null    object
#  3   Barnet                329 non-null    object
#  4   Bexley                329 non-null    object
#  5   Brent                 329 non-null    object
#  6   Bromley               329 non-null    object
#  7   Camden                329 non-null    object
#  8   Croydon               329 non-null    object
#  9   Ealing                329 non-null    object
#  10  Enfield               329 non-null    object
#  11  Greenwich             329 non-null    object
#  12  Hackney               329 non-null    object
#  13  Hammersmith & Fulham  329 non-null    object
# ...

# %%
# a view of the data frame head and tail; there's an abundance of dates, floating-point values, & identifiers
print(properties.head())
print("\n")
print(properties.tail())
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %%
# identify features missing values
properties.isna().sum().reset_index()
# Out:
#                    index    0
# 0             Unnamed: 0    1
# 1         City of London    0
# 2     Barking & Dagenham    0
# 3                 Barnet    0
# 4                 Bexley    0
# 5                  Brent    0
# 6                Bromley    0
# 7                 Camden    0
# 8                Croydon    0
# 9                 Ealing    0
# 10               Enfield    0
# 11             Greenwich    0
# 12               Hackney    0
# 13  Hammersmith & Fulham    0
# 14              Haringey    0
# 15                Harrow    0
# 16              Havering    0
# 17            Hillingdon    0
# 18              Hounslow    0
# 19             Islington    0
# 20  Kensington & Chelsea    0
# 21  Kingston upon Thames    0
# 22               Lambeth    0
# 23              Lewisham    0
# 24                Merton    0
# 25                Newham    0
# 26             Redbridge    0
# 27  Richmond upon Thames    0
# 28             Southwark    0
# 29                Sutton    0
# ...

# %%
print("There are "+ str(len(properties)) + " rows in the dataframe." " The unnamed columns (except the first) are missing all " + str(len(properties)) + " values \n" + "and, thus, can be dropped.")
# Out:
# There are 329 rows in the dataframe. The unnamed columns (except the first) are missing all 329 values
# and, thus, can be dropped.

# %%
# drop empty columns, as these have no probative value and/or contains data on regions that are *not* boroughs of London
properties.drop(['Unnamed: 34', 'Unnamed: 37', 'Unnamed: 47', 'City of London','Inner London', 'Outer London', 'NORTH EAST', 'NORTH WEST', 'EAST MIDLANDS', 'WEST MIDLANDS',
'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 'SOUTH WEST', 'England', 'YORKS & THE HUMBER'], inplace=True, axis=1)

# %%
# change name of date-time column to something more meaningful
properties = properties.rename(columns={"Unnamed: 0" : "dates"})
properties.tail()
# Out:
#          dates barking_&_dagenham       barnet       bexley        brent  \
# 323 2021-12-01        329557.0047  583195.3087  379526.3458  518958.5856
# 324 2022-01-01        338869.7029  580179.6373  382270.4215   519652.186
# 325 2022-02-01        345001.3576  576485.8755  387171.1018  525664.3639
# 326 2022-03-01        346064.5259  576689.7495  393246.1533  532006.6781
# 327 2022-04-01        336125.8982  596898.1846  392154.9821  546934.1163
#
#          bromley       camden      croydon       ealing      enfield  ...  \
# 323  476969.7846  889160.0227  404118.1402  516851.7744  432808.7906  ...
# 324  477940.5654  862346.1416  402782.4332  518836.7152  430460.8348  ...
# 325  482488.4382  844906.0505  406092.0046  525004.1651  433629.3853  ...
# 326  488167.0019   860277.973  412616.1388  532883.1655  435443.7257  ...
# 327  495549.8738  874080.5433  417946.8683  525438.3054   449967.405  ...
#
#           merton       newham    redbridge richmond_upon_thames    southwark  \
# ...

# %%
# drop row containing identifiers meaningful to only the person(s) generating the raw data set
properties.drop([0], axis = 0, inplace = True)

# %%
properties.head()
# Out:
#        dates Barking & Dagenham       Barnet       Bexley        Brent  \
# 1 1995-01-01         50460.2266  93284.51832  64958.09036  71306.56698
# 2 1995-02-01        51085.77983  93190.16963  64787.92069  72022.26197
# 3 1995-03-01        51268.96956  92247.52435  64367.49344  72015.76274
# 4 1995-04-01        53133.50526  90762.87492  64277.66881  72965.63094
# 5 1995-05-01        53042.24852  90258.00033  63997.13588  73704.04743
#
#        Bromley       Camden      Croydon       Ealing      Enfield  ...  \
# 1  81671.47692  120932.8881  69158.16225  79885.89069  72514.69096  ...
# 2  81657.55944  119508.8622  68951.09542  80897.06551  73155.19746  ...
# 3  81449.31143  120282.2131  68712.44341  81379.86288  72190.44144  ...
# 4  81124.41227   120097.899  68610.04641  82188.90498  71442.92235  ...
# 5  81542.61561  119929.2782   68844.9169  82077.05525  70630.77955  ...
#
#         Merton       Newham    Redbridge Richmond upon Thames    Southwark  \
# ...

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties.set_index('dates', inplace=True)

# %%
properties.tail()
# Out:
#          dates barking_&_dagenham       barnet       bexley        brent  \
# 323 2021-12-01        329557.0047  583195.3087  379526.3458  518958.5856
# 324 2022-01-01        338869.7029  580179.6373  382270.4215   519652.186
# 325 2022-02-01        345001.3576  576485.8755  387171.1018  525664.3639
# 326 2022-03-01        346064.5259  576689.7495  393246.1533  532006.6781
# 327 2022-04-01        336125.8982  596898.1846  392154.9821  546934.1163
#
#          bromley       camden      croydon       ealing      enfield  ...  \
# 323  476969.7846  889160.0227  404118.1402  516851.7744  432808.7906  ...
# 324  477940.5654  862346.1416  402782.4332  518836.7152  430460.8348  ...
# 325  482488.4382  844906.0505  406092.0046  525004.1651  433629.3853  ...
# 326  488167.0019   860277.973  412616.1388  532883.1655  435443.7257  ...
# 327  495549.8738  874080.5433  417946.8683  525438.3054   449967.405  ...
#
#           merton       newham    redbridge richmond_upon_thames    southwark  \
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
# replace spaces in column names w/ underscore
properties.columns = properties.columns.str.replace(' ', '_')

# change col names to lower case (personal preference)
properties.columns = properties.columns.str.lower()
properties.head()
# Out:
#            barking_&_dagenham       barnet       bexley        brent  \
# dates
# 1995-01-01         50460.2266  93284.51832  64958.09036  71306.56698
# 1995-02-01        51085.77983  93190.16963  64787.92069  72022.26197
# 1995-03-01        51268.96956  92247.52435  64367.49344  72015.76274
# 1995-04-01        53133.50526  90762.87492  64277.66881  72965.63094
# 1995-05-01        53042.24852  90258.00033  63997.13588  73704.04743
#
#                 bromley       camden      croydon       ealing      enfield  \
# dates
# 1995-01-01  81671.47692  120932.8881  69158.16225  79885.89069  72514.69096
# 1995-02-01  81657.55944  119508.8622  68951.09542  80897.06551  73155.19746
# 1995-03-01  81449.31143  120282.2131  68712.44341  81379.86288  72190.44144
# 1995-04-01  81124.41227   120097.899  68610.04641  82188.90498  71442.92235
# 1995-05-01  81542.61561  119929.2782   68844.9169  82077.05525  70630.77955
#
#               greenwich  ...       merton       newham    redbridge  \
# ...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
properties.reset_index(inplace=True)
properties_melt = pd.melt(properties, id_vars='dates', var_name='london_borough', value_name='average_price')
properties_melt
# Out:
#            dates      london_borough average_price
# 0     1995-01-01  barking_&_dagenham    50460.2266
# 1     1995-02-01  barking_&_dagenham   51085.77983
# 2     1995-03-01  barking_&_dagenham   51268.96956
# 3     1995-04-01  barking_&_dagenham   53133.50526
# 4     1995-05-01  barking_&_dagenham   53042.24852
# ...          ...                 ...           ...
# 10491 2021-12-01         westminster   1033172.155
# 10492 2022-01-01         westminster   1014964.961
# 10493 2022-02-01         westminster   1012521.105
# 10494 2022-03-01         westminster    981804.544
# 10495 2022-04-01         westminster    977553.758
#
# [10496 rows x 3 columns]

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
# https://stackoverflow.com/questions/15891038
properties_melt['average_price'] = properties_melt['average_price'].astype('float')
properties_melt['london_borough'] = properties_melt['london_borough'].astype('category')
properties_melt.dtypes
# Out:
# dates             datetime64[ns]
# london_borough          category
# average_price            float64
# dtype: object

# %%
# adding year and month columns for later visualization(s); this is asked for towards the end of the assignment, but
# I've done this type of work before.
properties_melt['year'] = pd.DatetimeIndex(properties_melt['dates']).year
properties_melt['month_int'] = pd.DatetimeIndex(properties_melt['dates']).month

# https://stackoverflow.com/questions/37625334/
properties_melt['month'] = pd.to_datetime(properties_melt['month_int'], format='%m').dt.month_name().str[:3]
properties_melt.head()
# Out:
#        dates      london_borough  average_price  year  month_int month
# 0 1995-01-01  barking_&_dagenham    50460.22660  1995          1   Jan
# 1 1995-02-01  barking_&_dagenham    51085.77983  1995          2   Feb
# 2 1995-03-01  barking_&_dagenham    51268.96956  1995          3   Mar
# 3 1995-04-01  barking_&_dagenham    53133.50526  1995          4   Apr
# 4 1995-05-01  barking_&_dagenham    53042.24852  1995          5   May

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
print("The number of average prices in the melted/tidy data set is " + str(len(properties_melt['average_price'])) + ".")
print("The number of months in the melted/tidy data set is " + str(len(properties_melt['month'])) + ".")
print("The number of missing values in the melted/tidy london_boroughs column is " + str(properties_melt['london_borough'].isnull().sum()) + ".")
print("The number of missing values in the melted/tidy average_price column is " + str(properties_melt['london_borough'].isnull().sum()) + ".")
print("The number of values in the melted/tidy london_boroughs column is " + str(int(properties_melt['london_borough'].count())) + ".")
# Out:
# The number of average prices in the melted/tidy data set is 10496.
# The number of months in the melted/tidy data set is 10496.
# The number of missing values in the melted/tidy london_boroughs column is 0.
# The number of missing values in the melted/tidy average_price column is 0.
# The number of values in the melted/tidy london_boroughs column is 10496.

# %%
print("The number of unique values in the london_boroughs column: " + str(int(properties_melt['london_borough'].nunique())) + ". This is the correct number of boroughs." )
# Out:
# The number of unique values in the london_boroughs column: 32. This is the correct number of boroughs.

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
# above suggestion has no probative value; restricted data to full year 2021
means_by_month = properties_melt[(properties_melt.london_borough == 'westminster') & (properties_melt.year == 2021)].groupby(['month'])['average_price'].mean()
means_by_month_rev = means_by_month.reset_index()

# https://www.youtube.com/watch?v=K2vSth7K7Ec -- sorting by month
sort_order = ('Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec')
means_by_month_rev.index = pd.CategoricalIndex(means_by_month_rev['month'], categories=sort_order, ordered = True) 
means_by_month_rev = means_by_month_rev.sort_index().reset_index(drop=True)

# using the sorted order requires you to specify 'x' then 'y' vars; using whole df causes numpy error
plt.plot(means_by_month_rev['month'], means_by_month_rev['average_price']);
plt.title("Average Property Price by Month in 2021: Westminster Borough, London", size=14, y=1.1);
plt.xlabel("Month", size=14);
plt.ylabel("Average Price", size=14);
plt.ticklabel_format(useOffset=False, style='plain', axis='y')

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
means_by_year = properties_melt[(properties_melt.year == 2002) | (properties_melt.year == 2022)].groupby(['london_borough', 'year'])['average_price'].mean()
means_by_year = means_by_year.unstack()
means_by_year['pct_change'] = round(((means_by_year[means_by_year.columns[1]]/means_by_year[means_by_year.columns[0]])-1)*100, 2)

temp = means_by_year.reset_index()
#https://stackoverflow.com/questions/10202570/
print("The average price in " + str(temp.iloc[temp['pct_change'].idxmax()]['london_borough'].capitalize()) + " has increased approximately " + str(temp.iloc[temp['pct_change'].idxmax()]['pct_change']) + "% over the last 20 years.")
# Out:
# The average price in Hackney has increased approximately 246.26% over the last 20 years.

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
ratios = properties_melt[(properties_melt.year == 1998) | (properties_melt.year == 2018)].groupby(['london_borough', 'year'])['average_price'].mean()
ratios = ratios.unstack()
ratios['price_ratio'] = ratios[ratios.columns[0]]/ratios[ratios.columns[1]]
ratios['diff_levels'] = ratios[ratios.columns[1]]-ratios[ratios.columns[0]]
ratios['price_multiple'] = ratios[ratios.columns[1]]/ratios[ratios.columns[0]]
plotting_ratios = ratios.reset_index()

plt.bar(plotting_ratios['london_borough'], plotting_ratios['price_ratio'])
plt.title("Average Property Price Ratio in London Boroughs: 1998/2019", size=14, y=1.01);
plt.xlabel("Borough", size=16);
plt.ylabel("Average Price Ratio (1998/2018)", size=14);
plt.ticklabel_format(useOffset=False, style='plain', axis='y')
# https://stackabuse.com/rotate-axis-labels-in-matplotlib/
plt.xticks(fontsize=14, rotation = 90);
plt.yticks(fontsize=14);
plt.rcParams["figure.figsize"] = (12,6);

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# We can summarize our findings by stating that London was expensive in the mid-1990s and has only become moreso in decades hence. Our data set contained average property prices for every London Borough for each day and year from 01/01/1995 to 04/01/2022. We validated the identities of each London Borough using the appropriate Wikipedia page; there are 32 such divisions. The data were complete for each region, so missing values were of no concern. We were, however, unable to establish if the data had been adjusted for inflation. When choices were given between writing a function and using vectorized operations, we opted for vectorization, as iteration over dataframe rows is widely regarded as a sub-optimal approach and revelatory of a lack of training in linear algebra.
#
# We tentatively draw the following conclusions from our data. First, property values seem to vary based on the time of year. For example, we saw that average property values for the borough of Westminster declined throughout the Spring, bottomed in June, and then peaked in August. Similar patterns in the remaining 31 boroughs are likely to be present. Prices have been far from static over the last ~27 years. Consider the borough of Hackney: Average prices increased approximately 246.26% over the last 20 years alone. In fact, the average property value in Hackney in 1998 was 15% of its 2018 value. The bar graph above suggests this was the general trend across all boroughs between 1998 and 2018, though not to the same extent.
#
# While our data indicate an upward trend exists among average property values in London, it does little to tell us why. Information on demographic transition and business formation would help explain why the average price of property in one of London's Boroughs has increased over the last ~27 years. Furthermore, additional socio-economic data would provide a basis for predictive and/or inferential statistical modeling of property value. Future research should focus on the affect of Brexit, as well as the global pandemic, on London property values. This would help business decision makers identify the most resilient boroughs in London in which to operate and/or reside.
